# %%
import pandas as pd

# %%
df=pd.read_csv('fifa_players.csv')
df.head()
# Out:
#            name                       full_name birth_date  age  height_cm  \
# 0      L. Messi  Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# 1    C. Eriksen    Christian  Dannemann Eriksen  2/14/1992   27     154.94
# 2      P. Pogba                      Paul Pogba  3/15/1993   25     190.50
# 3    L. Insigne                 Lorenzo Insigne   6/4/1991   27     162.56
# 4  K. Koulibaly               Kalidou Koulibaly  6/20/1991   27     187.96
#
#    weight_kgs  positions nationality  overall_rating  potential  ...  \
# 0        72.1   CF,RW,ST   Argentina              94         94  ...
# 1        76.2  CAM,RM,CM     Denmark              88         89  ...
# 2        83.9     CM,CAM      France              88         91  ...
# 3        59.0      LW,ST       Italy              88         88  ...
# 4        88.9         CB     Senegal              88         91  ...
#
#    long_shots  aggression interceptions  positioning  vision  penalties  \
# ...

# %% [markdown]
# # let's type all codes

# %%
df.columns
# Out:
# Index(['name', 'full_name', 'birth_date', 'age', 'height_cm', 'weight_kgs',
#        'positions', 'nationality', 'overall_rating', 'potential', 'value_euro',
#        'wage_euro', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'body_type',
#        'release_clause_euro', 'national_team', 'national_rating',
#        'national_team_position', 'national_jersey_number', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %%
df = df.set_index("name")
df
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %% [markdown]
# tepadagi kodda hamma boshidagi index larini olib quydi

# %% [markdown]
# # indexlarini joyiga quyib quyish

# %%
df=df.reset_index()

# %% [markdown]
# bunda esa hammasi joyiga qaytdi

# %% [markdown]
# # Indexes make subsetting simpler

# %%
df[df["name"].isin(["L. Messi","P. Pogba"])]
# Out:
#        name                       full_name birth_date  age  height_cm  \
# 0  L. Messi  Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# 2  P. Pogba                      Paul Pogba  3/15/1993   25     190.50
#
#    weight_kgs positions nationality  overall_rating  potential  ...  \
# 0        72.1  CF,RW,ST   Argentina              94         94  ...
# 2        83.9    CM,CAM      France              88         91  ...
#
#    long_shots  aggression interceptions  positioning  vision  penalties  \
# 0          94          48            22           94      94         75
# 2          82          78            64           82      88         82
#
#   composure  marking standing_tackle  sliding_tackle
# 0        96       33              28              26
# 2        87       63              67              67
#
# [2 rows x 51 columns]

# %% [markdown]
# # index buyicha chopish

# %%
df2 = df.set_index("full_name")
print(df2)
# Out:
#                                             name birth_date  age  height_cm  \
# full_name
# Lionel Andrés Messi Cuccittini          L. Messi  6/24/1987   31     170.18
# Christian  Dannemann Eriksen          C. Eriksen  2/14/1992   27     154.94
# Paul Pogba                              P. Pogba  3/15/1993   25     190.50
# Lorenzo Insigne                       L. Insigne   6/4/1991   27     162.56
# Kalidou Koulibaly                   K. Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# Rory  McKenzie                       R. McKenzie  10/7/1993   25     175.26
# Michal Sipľak                          M. Sipľak   2/2/1996   23     182.88
# Jan Bekkema                           J. Bekkema   4/9/1996   22     185.42
# Abdulrahman Al Yami                   A. Al Yami  6/19/1997   21     175.26
# José Francisco dos Santos Júnior  Júnior Brumado  5/15/1999   19     190.50
#
# ...

# %% [markdown]
# # Subsetting on duplicated index values -> bunda yani qiymat ichidagilarga murojat qilish

# %%
df=df.set_index('name')

# %% [markdown]
# # loc ni ishlatilishi

# %%
df.loc['L. Messi']
# Out:
# full_name                        Lionel Andrés Messi Cuccittini
# birth_date                                            6/24/1987
# age                                                          31
# height_cm                                                170.18
# weight_kgs                                                 72.1
# positions                                              CF,RW,ST
# nationality                                           Argentina
# overall_rating                                               94
# potential                                                    94
# value_euro                                          110500000.0
# wage_euro                                              565000.0
# preferred_foot                                             Left
# international_reputation(1-5)                                 5
# weak_foot(1-5)                                                4
# skill_moves(1-5)                                              4
# ...

# %%
df.head()
# Out:
#                                    full_name birth_date  age  height_cm  \
# name
# L. Messi      Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                          Paul Pogba  3/15/1993   25     190.50
# L. Insigne                   Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly               Kalidou Koulibaly  6/20/1991   27     187.96
#
#               weight_kgs  positions nationality  overall_rating  potential  \
# name
# L. Messi            72.1   CF,RW,ST   Argentina              94         94
# C. Eriksen          76.2  CAM,RM,CM     Denmark              88         89
# P. Pogba            83.9     CM,CAM      France              88         91
# L. Insigne          59.0      LW,ST       Italy              88         88
# K. Koulibaly        88.9         CB     Senegal              88         91
#
# ...

# %%
df2.iloc[2:5, 1:4]
# Out:
#                   birth_date  age  height_cm
# full_name
# Paul Pogba         3/15/1993   25     190.50
# Lorenzo Insigne     6/4/1991   27     162.56
# Kalidou Koulibaly  6/20/1991   27     187.96

# %%
df.loc["L. Messi":"L. Insigne"]
# Out:
#                                  full_name birth_date  age  height_cm  \
# name
# L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen    Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                        Paul Pogba  3/15/1993   25     190.50
# L. Insigne                 Lorenzo Insigne   6/4/1991   27     162.56
#
#             weight_kgs  positions nationality  overall_rating  potential  \
# name
# L. Messi          72.1   CF,RW,ST   Argentina              94         94
# C. Eriksen        76.2  CAM,RM,CM     Denmark              88         89
# P. Pogba          83.9     CM,CAM      France              88         91
# L. Insigne        59.0      LW,ST       Italy              88         88
#
#              value_euro  ...  long_shots aggression  interceptions  \
# name                     ...
# L. Messi    110500000.0  ...          94         48             22
# C. Eriksen   69500000.0  ...          89         46             56
# ...

# %% [markdown]
# # index va colum buyicha chopish

# %%
df.iloc[1:5, 2:4]
# Out:
#               age  height_cm
# name
# C. Eriksen     27     154.94
# P. Pogba       25     190.50
# L. Insigne     27     162.56
# K. Koulibaly   27     187.96
