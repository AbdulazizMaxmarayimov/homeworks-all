# %% [markdown]
# # Kirish

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
economy_USA=pd.read_csv("employment.csv")
economy_USA.head()
# Out:
#    year   all  16-24  25-54  55-64   65+  less_than_hs  high_school  \
# 0  2022  58.5   50.3   77.8   62.1  18.1          35.9         53.3
# 1  2021  56.5   45.6   75.3   60.1  17.8          33.4         51.1
# 2  2020  60.8   51.3   80.0   63.7  19.6          37.1         56.7
# 3  2019  60.5   50.4   79.4   63.2  19.0          37.1         56.2
# 4  2018  60.1   50.4   78.7   62.6  18.6          36.6         55.8
#
#    some_college  bachelors_degree  ...  white_men_16-24  white_men_25-54  \
# 0          59.6              69.7  ...             54.2             85.5
# 1          57.1              67.9  ...             50.1             83.9
# 2          62.5              72.0  ...             55.0             87.8
# 3          62.6              72.1  ...             54.2             87.6
# 4          62.7              71.8  ...             54.4             86.8
#
#    white_men_55-64  white_men_65+  white_men_less_than_hs  \
# ...

# %% [markdown]
# ## let's start all databases

# %%
fig, ax = plt.subplots()
ax.plot(economy_USA['year'], economy_USA['high_school'])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(economy_USA["year"].head(6), economy_USA['high_school'].head(6), marker='o', linestyle='--', color='green')
ax.set_title('Employment-to-Population Ratio for USA', loc='left', fontsize=12, color = 'blue')  
ax.set_xlabel('Y E A R')
ax.set_ylabel('high_school (percentage %)')
plt.show()

# %% [markdown]
# bunda har doimgidek ichidagi malumotlarini uzgartirish

# %%
medals = pd.read_csv('employment.csv')
fig, ax = plt.subplots()

# austin_weather = pd.DataFrame(data)

ax.bar(economy_USA["year"].head(6), economy_USA['high_school'].head(6))
plt.show()

# %% [markdown]
# bunda hozir bar graph ishladim va unga ichiga yozmoqchiman

# %%
fig, ax = plt.subplots()

ax.bar(economy_USA["year"].head(6).sort_values(), economy_USA['high_school'].head(6).sort_values(), color='green')
ax.set_title('Employment-to-Population Ratio for USA', loc='left', fontsize=12, color='blue')  
ax.set_xlabel('Y E A R')
ax.set_ylabel('high_school (percentage %)')
plt.show()

# %% [markdown]
# DONE. bunda sorlandi va rangi uzgartirildi

# %% [markdown]
# ## Interpreting boxplots

# %%
fig, ax = plt.subplots()
ax.boxplot([economy_USA["year"].head(12)])
ax.set_xticklabels(["year"])
ax.set_ylabel("Height (cm)")
plt.show()

# %% [markdown]
# ## Scatter plots

# %%
fig, ax = plt.subplots()
ax.scatter(economy_USA["year"], economy_USA["high_school"])
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(economy_USA["year"].head(6), economy_USA["high_school"].head(6), color = 'green')
ax.set_title('Employment-to-Population Ratio for USA', loc='left', fontsize=12, color = 'blue')  
ax.set_xlabel('Y E A R')
ax.set_ylabel('high_school (percentage %)')
plt.show()

# %% [markdown]
# bunda ichidagi har yillikni anniq kurish uchun va shuningdek label lar yaratish

# %%
fig, ax = plt.subplots()
ax.scatter(economy_USA["year"], economy_USA["high_school"], c=economy_USA.index)
ax.set_xlabel('Y E A R')
ax.set_ylabel('high_school (percentage %)')
plt.show()

# %% [markdown]
# Encoding a third variable by color - bunda liner uzgargan sari yani vaqt utgan sari ranglarni uzgarib borishi

# %% [markdown]
# ## hammasini bitta table ga joylashitrish

# %%
plt.style.use("ggplot")
# ax.set_title('Employment-to-Population Ratio for USA', loc='left', fontsize=12, color = 'blue')  
fig, ax= plt.subplots(2,2)
ax[0,0].scatter(economy_USA["year"], economy_USA["high_school"], c=economy_USA.index)
ax[0,0].set_xlabel("PRCP", color="b")
ax[0,0].set_ylabel("TAVG", color="r")
ax[0,0].set_title("SEATTLE", color="y")

ax[1,0].bar(("2020"), economy_USA["high_school"].mean(), yerr=economy_USA["high_school"].std())
ax[1,0].bar(("2019"), economy_USA["high_school"].mean(), yerr=economy_USA["high_school"].std())
ax[1,0].set_ylabel("Height", color="b")
ax[1,0].set_xlabel("Y e a r", color="b")


ax[0,1].hist(economy_USA["year"].head(6), label=economy_USA['high_school'].head(6))
ax[1,1].boxplot([economy_USA["high_school"].head(12)])
ax[1,1].set_xticklabels(["year"])
ax[0][0].grid(True, color="b")
fig.set_size_inches([7,7])
plt.show()

# %% [markdown]
# shuningdek bunda hammasini bittasiga solib quydim
