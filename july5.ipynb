# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
df = pd.read_csv("data_to_clean.csv")
df.head()
# Out:
#    Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0      244485       0  1.240299     18                NaN -0.588101
# 1      115340       0       NaN     22                NaN       NaN
# 2       68357       0       NaN      8                NaN       NaN
# 3      368377       0  1.075660     24                NaN  0.402080
# 4      384684       0       NaN     11                NaN       NaN
#
#    Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  \
# 0         0.309404      TB              0             NaN  ...
# 1         0.198142     OAK              0             NaN  ...
# 2         0.000000     NYJ              0             NaN  ...
# 3         0.258227     CLE              0             NaN  ...
# 4         0.199771     DEN              0             NaN  ...
#
#    Accepted.Penalty qtr  AwayTimeouts_Remaining_Post  RunGap  Reception  \
# 0                 0   3                            3     NaN          1
# ...

# %%
df
# Out:
#        Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0          244485       0  1.240299     18                NaN -0.588101
# 1          115340       0       NaN     22                NaN       NaN
# 2           68357       0       NaN      8                NaN       NaN
# 3          368377       0  1.075660     24                NaN  0.402080
# 4          384684       0       NaN     11                NaN       NaN
# ...           ...     ...       ...    ...                ...       ...
# 40764       79438       0       NaN      3                NaN       NaN
# 40765      398233       0       NaN      9                NaN       NaN
# 40766      396466       0       NaN      8                NaN       NaN
# 40767      333861       0  0.025040     14                NaN  0.280049
# 40768      247608       0 -2.441755      6                NaN  1.692283
#
#        Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  \
# ...

# %%
print(df['yacEPA'].isnull().sum())
# Out:
# 24902

# %%
# df.dropna(how='any')

# %%
df.dropna(subset=['RunGap'])
# Out:
#        Unnamed: 0  Safety  yacEPA  Drive  FieldGoalDistance  airEPA  \
# 4          384684       0     NaN     11                NaN     NaN
# 11         246343       0     NaN     25                NaN     NaN
# 14         161472       0     NaN     21                NaN     NaN
# 17          48918       0     NaN      1                NaN     NaN
# 18         244580       0     NaN      9                NaN     NaN
# ...           ...     ...     ...    ...                ...     ...
# 40751      249210       0     NaN     21                NaN     NaN
# 40752      112932       0     NaN      5                NaN     NaN
# 40764       79438       0     NaN      3                NaN     NaN
# 40765      398233       0     NaN      9                NaN     NaN
# 40766      396466       0     NaN      8                NaN     NaN
#
#        Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  \
# 4             0.199771     DEN              0             NaN  ...
# ...

# %% [markdown]
# bu yerda dropna ishlatilishi orqali qayerda NAN qatnaashgan bulsa olib tashlanadi

# %%
df['FieldGoalResult'].fillna(
value='None Given')
# Out:
# 0        None Given
# 1        None Given
# 2        None Given
# 3        None Given
# 4        None Given
#             ...
# 40764    None Given
# 40765    None Given
# 40766    None Given
# 40767    None Given
# 40768    None Given
# Name: FieldGoalResult, Length: 40769, dtype: object

# %% [markdown]
# bunda biz bilishimiz mumkinki buni ishlatish orqali qayerda NaN qatnashgan bulsa ushalarni hammasini urniga None given quyib chiqadi

# %%
mean_drive = df['Drive'].mean()
df['NEW_Drive'] = df['Drive'].fillna(value=mean_drive)
df['NEW_Drive']=df['NEW_Drive'].mean()
df.head()
# Out:
#    Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0      244485       0  1.240299     18                NaN -0.588101
# 1      115340       0       NaN     22                NaN       NaN
# 2       68357       0       NaN      8                NaN       NaN
# 3      368377       0  1.075660     24                NaN  0.402080
# 4      384684       0       NaN     11                NaN       NaN
#
#    Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  qtr  \
# 0         0.309404      TB              0             NaN  ...    3
# 1         0.198142     OAK              0             NaN  ...    4
# 2         0.000000     NYJ              0             NaN  ...    2
# 3         0.258227     CLE              0             NaN  ...    4
# 4         0.199771     DEN              0             NaN  ...    2
#
#   AwayTimeouts_Remaining_Post  RunGap  Reception  TimeUnder  Season  \
# 0                           3     NaN          1          1    2014
# ...

# %% [markdown]
# bu yerda qushimcha ustun qushildi NEW_Drive degan va unga uzini maulmotlarini yukladi va uning urtacha qiymatini topildi

# %%
print(df['airEPA'].dtype)
# Out:
# float64

# %% [markdown]
# just checking the type of the **airEPA**

# %%
print(df['posteam'].dtype)
# Out:
# object

# %% [markdown]
# bu yerda object qismini topib olishimiz kere shunda biz u yerdagi hamma qatnashgan vergul va qushimcha qatnashgan larni uchirib chiqamiz

# %%
df['posteam'].str.replace('[$%ۣ]', '')
# Out:
# 0         TB
# 1        OAK
# 2        NYJ
# 3        CLE
# 4        DEN
#         ...
# 40764     NO
# 40765    DEN
# 40766    ATL
# 40767    IND
# 40768    CIN
# Name: posteam, Length: 40769, dtype: object
