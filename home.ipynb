# %%
import pandas as pd
df=pd.read_csv('football.csv')
df
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0             24.367182                    28                    16
# 1             34.162143                    89                    12
# 2             30.443897                    43                     3
# 3             28.177194                    84                    19
# 4             20.652317                    36                    36
# ...                 ...                   ...                   ...
# 49995         28.581568                    93                    27
# 49996         21.845291                    93                    20
# 49997         30.732916                    88                    34
# 49998         26.857186                    78                    22
# 49999         32.649014                    61                    28
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                          36                     20
# ...

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
df.sort_index()
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0             24.367182                    28                    16
# 1             34.162143                    89                    12
# 2             30.443897                    43                     3
# 3             28.177194                    84                    19
# 4             20.652317                    36                    36
# ...                 ...                   ...                   ...
# 49995         28.581568                    93                    27
# 49996         21.845291                    93                    20
# 49997         30.732916                    88                    34
# 49998         26.857186                    78                    22
# 49999         32.649014                    61                    28
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                          36                     20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   AveragePlayerAge              50000 non-null  float64
#  1   TotalGoalsLastSeason          50000 non-null  int64
#  2   MatchesWonLastSeason          50000 non-null  int64
#  3   MatchesDrawnLastSeason        50000 non-null  int64
#  4   MatchesLostLastSeason         50000 non-null  int64
#  5   TotalGoalsConcededLastSeason  50000 non-null  int64
#  6   TotalRevenueLastSeason        50000 non-null  float64
#  7   StadiumCapacity               50000 non-null  int64
#  8   AverageAttendance             50000 non-null  float64
#  9   TransferSpendingLastSeason    50000 non-null  float64
#  10  TransferIncomeLastSeason      50000 non-null  float64
#  11  NumberOfTrophies              50000 non-null  int64
# ...

# %%
df.head(n=10)
# Out:
#    AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0         24.367182                    28                    16
# 1         34.162143                    89                    12
# 2         30.443897                    43                     3
# 3         28.177194                    84                    19
# 4         20.652317                    36                    36
# 5         20.651907                    56                    14
# 6         18.987421                    69                    34
# 7         32.724994                    64                    22
# 8         28.218955                    39                    30
# 9         30.037234                    78                    14
#
#    MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                      36                     20
# 1                      35                     31
# 2                       9                     28
# 3                      19                     34
# ...

# %%
df.sort_values(["AveragePlayerAge", "MatchesWonLastSeason"])
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 33726         18.000094                    25                     9
# 2902          18.000198                    91                    13
# 42631         18.000285                    54                    36
# 4151          18.000522                    36                     1
# 21945         18.000818                    30                     4
# ...                 ...                   ...                   ...
# 41322         34.998140                    81                    35
# 21043         34.998317                    37                     3
# 15618         34.998722                    36                    25
# 46862         34.999268                    71                    19
# 43676         34.999527                    44                     0
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 33726                      24                     28
# ...

# %%
df.sort_values(["AveragePlayerAge", "MatchesWonLastSeason"])
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 33726         18.000094                    25                     9
# 2902          18.000198                    91                    13
# 42631         18.000285                    54                    36
# 4151          18.000522                    36                     1
# 21945         18.000818                    30                     4
# ...                 ...                   ...                   ...
# 41322         34.998140                    81                    35
# 21043         34.998317                    37                     3
# 15618         34.998722                    36                    25
# 46862         34.999268                    71                    19
# 43676         34.999527                    44                     0
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 33726                      24                     28
# ...

# %%
df.head()
# Out:
#    AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0         24.367182                    28                    16
# 1         34.162143                    89                    12
# 2         30.443897                    43                     3
# 3         28.177194                    84                    19
# 4         20.652317                    36                    36
#
#    MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                      36                     20
# 1                      35                     31
# 2                       9                     28
# 3                      19                     34
# 4                      10                      9
#
#    TotalGoalsConcededLastSeason  TotalRevenueLastSeason  StadiumCapacity  \
# 0                            51              337.552001            55766
# 1                            84              264.850402            15307
# ...

# %%
df.head()['AgAverage']=[102, 523, 2341, 1024, 2452]
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20244\3500133643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.head()['AgAverage']=[102, 523, 2341, 1024, 2452]
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0             24.367182                    28                    16
# 1             34.162143                    89                    12
# 2             30.443897                    43                     3
# 3             28.177194                    84                    19
# 4             20.652317                    36                    36
# ...                 ...                   ...                   ...
# 49995         28.581568                    93                    27
# ...

# %%
df["AverageAttendance"]
# Out:
# 0         5229.742720
# 1        46172.738882
# 2        78334.254989
# 3        60080.423819
# 4        10940.950513
#              ...
# 49995    41021.316020
# 49996    42936.194438
# 49997    32554.899828
# 49998    89923.247455
# 49999    64012.493588
# Name: AverageAttendance, Length: 50000, dtype: float64

# %%
df["StadiumCapacity"] > 61440
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 49995     True
# 49996    False
# 49997    False
# 49998     True
# 49999    False
# Name: StadiumCapacity, Length: 50000, dtype: bool

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   AveragePlayerAge              50000 non-null  float64
#  1   TotalGoalsLastSeason          50000 non-null  int64
#  2   MatchesWonLastSeason          50000 non-null  int64
#  3   MatchesDrawnLastSeason        50000 non-null  int64
#  4   MatchesLostLastSeason         50000 non-null  int64
#  5   TotalGoalsConcededLastSeason  50000 non-null  int64
#  6   TotalRevenueLastSeason        50000 non-null  float64
#  7   StadiumCapacity               50000 non-null  int64
#  8   AverageAttendance             50000 non-null  float64
#  9   TransferSpendingLastSeason    50000 non-null  float64
#  10  TransferIncomeLastSeason      50000 non-null  float64
#  11  NumberOfTrophies              50000 non-null  int64
# ...

# %% [markdown]
# ## normalize

# %%
df['TotalRevenueLastSeason'].value_counts(sort=True, normalize=True)
# Out:
# TotalRevenueLastSeason
# 337.552001    0.00002
# 72.960739     0.00002
# 233.287892    0.00002
# 220.066070    0.00002
# 257.728014    0.00002
#                ...
# 112.089622    0.00002
# 61.672181     0.00002
# 147.391245    0.00002
# 264.207373    0.00002
# 317.799796    0.00002
# Name: proportion, Length: 50000, dtype: float64

# %%
df
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0             24.367182                    28                    16
# 1             34.162143                    89                    12
# 2             30.443897                    43                     3
# 3             28.177194                    84                    19
# 4             20.652317                    36                    36
# ...                 ...                   ...                   ...
# 49995         28.581568                    93                    27
# 49996         21.845291                    93                    20
# 49997         30.732916                    88                    34
# 49998         26.857186                    78                    22
# 49999         32.649014                    61                    28
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                          36                     20
# ...

# %%
df['AveragePlayerAge'].value_counts()
# Out:
# AveragePlayerAge
# 24.367182    1
# 21.494040    1
# 27.231072    1
# 27.395938    1
# 29.651130    1
#             ..
# 30.212124    1
# 23.925293    1
# 27.985521    1
# 23.282949    1
# 32.649014    1
# Name: count, Length: 50000, dtype: int64

# %%
df['AveragePlayerAge'].value_counts(normalize=True)
# Out:
# AveragePlayerAge
# 24.367182    0.00002
# 21.494040    0.00002
# 27.231072    0.00002
# 27.395938    0.00002
# 29.651130    0.00002
#               ...
# 30.212124    0.00002
# 23.925293    0.00002
# 27.985521    0.00002
# 23.282949    0.00002
# 32.649014    0.00002
# Name: proportion, Length: 50000, dtype: float64

# %% [markdown]
# ## mean bilan qullanilishi

# %%
df["TotalGoalsLastSeason"].mean()
df
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0             24.367182                    28                    16
# 1             34.162143                    89                    12
# 2             30.443897                    43                     3
# 3             28.177194                    84                    19
# 4             20.652317                    36                    36
# ...                 ...                   ...                   ...
# 49995         28.581568                    93                    27
# 49996         21.845291                    93                    20
# 49997         30.732916                    88                    34
# 49998         26.857186                    78                    22
# 49999         32.649014                    61                    28
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                          36                     20
# ...

# %% [markdown]
# ## GROUPBY---> metodi guruhlash uchun qo'llaniladi

# %%
df.groupby("AveragePlayerAge")["TotalGoalsLastSeason"].mean()
# Out:
# AveragePlayerAge
# 18.000094    25.0
# 18.000198    91.0
# 18.000285    54.0
# 18.000522    36.0
# 18.000818    30.0
#              ...
# 34.998140    81.0
# 34.998317    37.0
# 34.998722    36.0
# 34.999268    71.0
# 34.999527    44.0
# Name: TotalGoalsLastSeason, Length: 50000, dtype: float64

# %% [markdown]
# # MULTIPLE SUMMARIES

# %%
df.head()
# Out:
#    AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0         24.367182                    28                    16
# 1         34.162143                    89                    12
# 2         30.443897                    43                     3
# 3         28.177194                    84                    19
# 4         20.652317                    36                    36
#
#    MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                      36                     20
# 1                      35                     31
# 2                       9                     28
# 3                      19                     34
# 4                      10                      9
#
#    TotalGoalsConcededLastSeason  TotalRevenueLastSeason  StadiumCapacity  \
# 0                            51              337.552001            55766
# 1                            84              264.850402            15307
# ...

# %%
df[df["TotalGoalsLastSeason"]==22].groupby("AveragePlayerAge")["MatchesWonLastSeason"].value_counts()
# Out:
# AveragePlayerAge  MatchesWonLastSeason
# 18.026607         13                      1
# 18.044747         13                      1
# 18.059622         12                      1
# 18.091222         23                      1
# 18.109539         25                      1
#                                          ..
# 34.878599         13                      1
# 34.886924         33                      1
# 34.915897         11                      1
# 34.924671         16                      1
# 34.971154         16                      1
# Name: count, Length: 623, dtype: int64

# %%
df[df["MatchesWonLastSeason"]==20].describe()
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# count       1342.000000           1342.000000                1342.0
# mean          26.383724             57.975410                  20.0
# std            4.972501             23.157409                   0.0
# min           18.011031             20.000000                  20.0
# 25%           21.956045             38.000000                  20.0
# 50%           26.395180             57.000000                  20.0
# 75%           30.686373             78.000000                  20.0
# max           34.990832             99.000000                  20.0
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# count             1342.000000            1342.000000
# mean                18.763040              18.301043
# std                 10.901657              11.199112
# min                  0.000000               0.000000
# 25%                 10.000000               8.000000
# ...

# %% [markdown]
# ## DROP_DUPLICATES--->metodi duplicate datalarni o'chirishda ishlatiladi

# %%
df.drop_duplicates("MatchesWonLastSeason")
# Out:
#      AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0           24.367182                    28                    16
# 1           34.162143                    89                    12
# 2           30.443897                    43                     3
# 3           28.177194                    84                    19
# 4           20.652317                    36                    36
# 5           20.651907                    56                    14
# 6           18.987421                    69                    34
# 7           32.724994                    64                    22
# 8           28.218955                    39                    30
# 11          34.488467                    30                    27
# 13          21.609765                    84                    11
# 14          21.091024                    96                    24
# 15          21.117877                    77                    31
# ...

# %% [markdown]
# ## CUMSUM()--->metodi har bir elementdan oldingi barcha elementlarning summasini hisoblab beradi

# %%
df["MatchesLostLastSeason"].cumsum()
# Out:
# 0            20
# 1            51
# 2            79
# 3           113
# 4           122
#           ...
# 49995    923876
# 49996    923898
# 49997    923902
# 49998    923905
# 49999    923905
# Name: MatchesLostLastSeason, Length: 50000, dtype: int64
