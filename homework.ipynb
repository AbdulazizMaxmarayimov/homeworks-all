# %% [markdown]
# # CSV ga kirish

# %%
import pandas as pd
df=pd.read_csv("salary_2024.csv")

# %% [markdown]
# ###  head()---> metodi cvs ichidan malumotlarni chiqarish uchun ishlatiladi, agar head() ga qiymat berilmasa default 5ta malumot chiqaradi

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %% [markdown]
# ### info()---> metodi berilgan malumotlar haqida umumiy ma'lumot beradi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16534 entries, 0 to 16533
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16534 non-null  int64
#  1   experience_level    16534 non-null  object
#  2   employment_type     16534 non-null  object
#  3   job_title           16534 non-null  object
#  4   salary              16534 non-null  int64
#  5   salary_currency     16534 non-null  object
#  6   salary_in_usd       16534 non-null  int64
#  7   employee_residence  16534 non-null  object
#  8   remote_ratio        16534 non-null  int64
#  9   company_location    16534 non-null  object
#  10  company_size        16534 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# ### shape---> metodi dataframe o'lchamini qaytaradi ya'ni nechta satr va ustundan iborat ekanligini!

# %%
df.shape
# Out:
# (16534, 11)

# %% [markdown]
# ### describe()---> metodi sonli malumotlarni, minimum, maksimum kabi malumotlarni chiqaradi

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  16534.000000  1.653400e+04   16534.000000  16534.000000
# mean    2023.226866  1.637270e+05  149686.777973     32.003750
# std        0.713558  3.402057e+05   68505.293156     46.245158
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.017630e+05  101125.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.872000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %% [markdown]
# ### values---> metodi malumotlarni NumPy shaklida qaytaradi

# %%
df.values
# Out:
# array([[2024, 'SE', 'FT', ..., 0, 'US', 'M'],
#        [2024, 'SE', 'FT', ..., 0, 'US', 'M'],
#        [2024, 'SE', 'FT', ..., 0, 'US', 'M'],
#        ...,
#        [2020, 'EN', 'FT', ..., 100, 'US', 'S'],
#        [2020, 'EN', 'CT', ..., 100, 'US', 'L'],
#        [2021, 'SE', 'FT', ..., 50, 'IN', 'L']], dtype=object)

# %% [markdown]
# ### columns---> metodi dataframe ning barcha ustun malumotlarini indekslangan obyekt sifatida qaytaradi

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ### index---> metodi dataframe ning barcha qator malumotlarini indekslangan obyekt sifatida qaytaradi

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16534, step=1)

# %% [markdown]
# ### sort_values()---> dataframe malumotlarini malum ustun yoki ustunlar bo'yicha tartiblaydi

# %%
df.sort_values("salary")
# Out:
#        work_year experience_level employment_type  \
# 16366       2020               EN              PT
# 10800       2022               MI              FT
# 15639       2021               EN              FT
# 5739        2024               EN              PT
# 13011       2020               EX              FT
# ...          ...              ...             ...
# 15768       2022               SE              FT
# 16271       2021               MI              FT
# 16364       2021               MI              FT
# 16434       2020               MI              FT
# 16455       2021               MI              FT
#
#                              job_title    salary salary_currency  \
# 16366                      ML Engineer     14000             EUR
# 10800  Business Intelligence Developer     15000             USD
# 15639       Machine Learning Developer     15000             USD
# 5739                      Data Science     15000             EUR
# ...

# %%
df.sort_values("salary", ascending=False)
# Out:
#        work_year experience_level employment_type  \
# 16455       2021               MI              FT
# 16434       2020               MI              FT
# 16364       2021               MI              FT
# 16271       2021               MI              FT
# 15768       2022               SE              FT
# ...          ...              ...             ...
# 15936       2022               EN              FT
# 5739        2024               EN              PT
# 10800       2022               MI              FT
# 13011       2020               EX              FT
# 16366       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 16455                   Data Scientist  30400000             CLP
# 16434                   Data Scientist  11000000             HUF
# 16364                  BI Data Analyst  11000000             HUF
# 16271                      ML Engineer   8500000             JPY
# ...

# %%
df.sort_values(["salary", "work_year"])
# Out:
#        work_year experience_level employment_type  \
# 16366       2020               EN              PT
# 13011       2020               EX              FT
# 15639       2021               EN              FT
# 10800       2022               MI              FT
# 15936       2022               EN              FT
# ...          ...              ...             ...
# 15768       2022               SE              FT
# 16271       2021               MI              FT
# 16434       2020               MI              FT
# 16364       2021               MI              FT
# 16455       2021               MI              FT
#
#                              job_title    salary salary_currency  \
# 16366                      ML Engineer     14000             EUR
# 13011               Staff Data Analyst     15000             USD
# 15639       Machine Learning Developer     15000             USD
# 10800  Business Intelligence Developer     15000             USD
# ...

# %% [markdown]
# ### df["column_name"]---> metodi dataframe ning malum bir ustunini olish uchun ishlatiladi va series obyekt sifatida qaytaradi

# %%
df["job_title"]
# Out:
# 0                      AI Engineer
# 1                      AI Engineer
# 2                    Data Engineer
# 3                    Data Engineer
# 4        Machine Learning Engineer
#                    ...
# 16529               Data Scientist
# 16530     Principal Data Scientist
# 16531               Data Scientist
# 16532        Business Data Analyst
# 16533         Data Science Manager
# Name: job_title, Length: 16534, dtype: object

# %% [markdown]
# ### df["salary"]<250000 ---> metodi berilgan qiymat bo'yicha taqqoslab chiqadi va true yoki false qaytaradi

# %%
df["salary"]<250000
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 16529    False
# 16530     True
# 16531     True
# 16532     True
# 16533    False
# Name: salary, Length: 16534, dtype: bool

# %% [markdown]
# ### df[df["salary"]<20000]---> metodi berilgan qiymatga mos keladigan malumotlarni chiqarib beradi

# %%
df[df["salary"]<20000]
# Out:
#        work_year experience_level employment_type  \
# 3518        2024               EN              FT
# 3519        2024               EN              FT
# 5739        2024               EN              PT
# 6870        2023               EN              FT
# 8580        2023               EN              FT
# 9057        2023               EN              FT
# 9384        2023               MI              FT
# 10337       2022               EN              FT
# 10800       2022               MI              FT
# 11650       2023               EN              FT
# 13011       2020               EX              FT
# 15639       2021               EN              FT
# 15936       2022               EN              FT
# 16366       2020               EN              PT
# 16491       2020               EN              PT
# 16500       2021               MI              FT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# ...

# %% [markdown]
# ### df[df["column_name"]==2020]---> metodi berilgan column da shu qiymatga teng bo'lgan malumotlarni chiqaradi

# %%
df["work_year"].describe()
# Out:
# count    16534.000000
# mean      2023.226866
# std          0.713558
# min       2020.000000
# 25%       2023.000000
# 50%       2023.000000
# 75%       2024.000000
# max       2024.000000
# Name: work_year, dtype: float64

# %% [markdown]
# ### df["new_column_name"]=df["column_name"]*10 ---> metodi yangi column qo'shishda ishlatiladi

# %%
df["boylar"]=df["salary"]*10
df
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 16529       2020               SE              FT             Data Scientist
# 16530       2021               MI              FT   Principal Data Scientist
# 16531       2020               EN              FT             Data Scientist
# 16532       2020               EN              CT      Business Data Analyst
# 16533       2021               SE              FT       Data Science Manager
#
# ...
